# %% [markdown]
# # missingno
#
# Missing data visualization module for Python.
#
# - https://github.com/ResidentMario/missingno

# %%
import missingno
# %matplotlib inline

import numpy as np
import pandas as pd

from quilt.data.ResidentMario import missingno_data # this is just to get the data

# %%
collisions = missingno_data.nyc_collision_factors()
collisions = collisions.replace("nan", np.nan)

# %%
missingno.matrix(collisions)
